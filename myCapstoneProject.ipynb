# %% [markdown]
# <h1>Coursera Capstone</h1>

# %% [markdown]
# <h3> 1. Write some markdown to explain that this notebook will be mainly used for the capstone project.</h3>
# <p> This notebook will be mainly used for the capstone project for IBM Applied Data Science Capstone course on Coursera.
# Thank you to all , nice to meet you ,and in this journey,i has learnt many new things whic.....</p>

# %%
# 2. Import the pandas library as pd 
import pandas as pd

# %%
# 3. Import the numpy Library as np
import numpy as np

# %%
# 4. Print the following the statement ; Hello Captone Project Course !
print("Hello Capstone Project Course !")
# Out:
# Hello Capstone Project Course !
